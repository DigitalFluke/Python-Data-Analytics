# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
epl_df = pd.read_csv(r"C:\Users\Dell\Downloads\datasets\arc\EPL_20_21.csv")

# %%
epl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %%
epl_df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
# Get total number of goals scored
total = epl_df['Goals'].sum()
total
# Out:
# 986

# %%
# Get the total number of goals scored by a team
# for those rows only where 'Club' is Chelsea
tota = epl_df.loc[epl_df['Club'] == 'Chelsea', 'Goals'].sum()
tota
# Out:
# 56

# %%
#Showing the total number of attributes by clubs
overall_data=epl_df.groupby(['Club']).sum()
overall_data[['Goals' , 'Assists' , 'Passes_Attempted', 'Penalty_Goals', 'xG', 'xA' , 'Yellow_Cards', 'Red_Cards']]
# Out:
#                          Goals  Assists  Passes_Attempted  Penalty_Goals  \
# Club
# Arsenal                     53       38             21291              6
# Aston Villa                 52       38             16556              5
# Brighton                    39       24             19456              6
# Burnley                     32       20             15043              3
# Chelsea                     56       38             25151              8
# Crystal Palace              39       29             15092              3
# Everton                     45       32             18246              4
# Fulham                      26       18             18860              3
# Leeds United                60       45             20043              4
# Leicester City              64       45             20572             10
# Liverpool FC                65       43             25526              6
# Manchester City             82       55             26688              5
# ...

# %%
#Showing the top goals by position
positional_goals=epl_df.groupby(['Position']).sum()
positional_goals[['Goals' , 'Assists' , 'Passes_Attempted', 'Penalty_Goals', 'xG', 'xA', 'Yellow_Cards', 'Red_Cards']]
# Out:
#           Goals  Assists  Passes_Attempted  Penalty_Goals     xG    xA  \
# Position
# DF          129      136            161862              1   6.42  7.00
# DF,FW         3        8              2209              0   1.38  0.65
# DF,MF        11       12             13201              0   1.17  0.64
# FW          442      172             31107             48  24.60  9.24
# FW,DF         8        8              2676              0   0.86  0.69
# FW,MF       124       99             21042              8   9.87  6.32
# GK            1        2             23879              0   0.00  0.08
# MF          171      162             93948             36   8.94  8.31
# MF,DF        14       18             12541              3   0.95  1.05
# MF,FW        83       68             19378              6   6.08  4.67
#
#           Yellow_Cards  Red_Cards
# Position
# DF                 443         26
# DF,FW                9          0
# DF,MF               36          1
# ...

# %%
#Top 20 Hihgest Goal Scorers in The league
golden_boot=epl_df.sort_values(by='Goals', ascending = False).head(20)
golden_boot
# Out:
#                       Name                  Club Nationality Position  Age  \
# 162             Harry Kane     Tottenham Hotspur         ENG       FW   27
# 81           Mohamed Salah          Liverpool FC         EGY       FW   28
# 51         Bruno Fernandes     Manchester United         POR       MF   25
# 214        Patrick Bamford          Leeds United         ENG       FW   26
# 161          Son Heung-min     Tottenham Hotspur         KOR       FW   28
# 237  Dominic Calvert-Lewin               Everton         ENG       FW   23
# 110            Jamie Vardy        Leicester City         ENG       FW   33
# 267          Ollie Watkins           Aston Villa         ENG       FW   24
# 33          İlkay Gündoğan       Manchester City         GER       MF   29
# 191    Alexandre Lacazette               Arsenal         FRA       FW   29
# 428             Chris Wood               Burnley         NZL       FW   28
# ...

# %%
#checking if the indexes are unique
epl_df.index.is_unique
# Out:
# True

# %%
epl_df.shape
# Out:
# (532, 18)

# %%
epl_df.corr()
# Out:
#                             Age   Matches    Starts      Mins     Goals  \
# Age                    1.000000  0.149628  0.156387  0.158643  0.047022
# Matches                0.149628  1.000000  0.938116  0.947351  0.441977
# Starts                 0.156387  0.938116  1.000000  0.997031  0.405381
# Mins                   0.158643  0.947351  0.997031  1.000000  0.400398
# Goals                  0.047022  0.441977  0.405381  0.400398  1.000000
# Assists                0.026740  0.508009  0.477704  0.474677  0.617831
# Passes_Attempted       0.120244  0.785362  0.853448  0.855600  0.201526
# Perc_Passes_Completed  0.122812  0.085462  0.086039  0.085460 -0.025137
# Penalty_Goals          0.084547  0.227929  0.216877  0.219027  0.594730
# Penalty_Attempted      0.083328  0.234389  0.221418  0.224115  0.590492
# xG                    -0.056098  0.192047  0.072487  0.075016  0.681959
# xA                    -0.047849  0.227570  0.113446  0.117602  0.348428
# ...

# %%
Teams=list(epl_df["Club"].unique())

# %%
corr_df =epl_df.drop(["Name","Club","Nationality","Position"],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df,annot=True,fmt=".1g", vmin=-1, vmax=1, center=0, cmap="inferno", linewidths=1, linecolor="black")
heatmap.set_title("Correlation HeatMap Between Variables")
heatmap.set_xticklabels(heatmap.get_xticklabels(),rotation=90)
# Out:
# [Text(0.5, 0, 'Age'),
#  Text(1.5, 0, 'Matches'),
#  Text(2.5, 0, 'Starts'),
#  Text(3.5, 0, 'Mins'),
#  Text(4.5, 0, 'Goals'),
#  Text(5.5, 0, 'Assists'),
#  Text(6.5, 0, 'Passes_Attempted'),
#  Text(7.5, 0, 'Perc_Passes_Completed'),
#  Text(8.5, 0, 'Penalty_Goals'),
#  Text(9.5, 0, 'Penalty_Attempted'),
#  Text(10.5, 0, 'xG'),
#  Text(11.5, 0, 'xA'),
#  Text(12.5, 0, 'Yellow_Cards'),
#  Text(13.5, 0, 'Red_Cards')]

# %%
Teams
# Out:
# ['Chelsea',
#  'Manchester City',
#  'Manchester United',
#  'Liverpool FC',
#  'Leicester City',
#  'West Ham United',
#  'Tottenham Hotspur',
#  'Arsenal',
#  'Leeds United',
#  'Everton',
#  'Aston Villa',
#  'Newcastle United',
#  'Wolverhampton Wanderers',
#  'Crystal Palace',
#  'Southampton',
#  'Brighton',
#  'Burnley',
#  'Fulham',
#  'West Bromwich Albion',
#  'Sheffield United']

# %%
epl_df.head(10).plot(x="Name", y=["Goals", "Assists"], kind="bar", stacked=True)
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
golden_boot.head(20).plot.bar(x='Name', y='Goals', rot=90).set(title="Top 20 Highest Goal Scorers")
plt.ylabel("Goals")
# Out:
# Text(0, 0.5, 'Goals')

# %%
#epl_df.head(10).plot(x="Name", y=["Goals", "Assists", "Penalty_Goals"], kind="bar")
golden_boot.head(10).plot.bar(x='Name', y=['Goals', 'Assists', 'Penalty_Goals'], rot=90).set(title="Goals, Assists and Penalties by Top 10 Goal Scorers")
plt.ylabel("Goals, Assists and Penatlties")
# Out:
# Text(0, 0.5, 'Goals, Assists and Penatlties')

# %%
golden_boot.head(10).plot(x="Name", y=["Goals", "Assists"], kind="bar", stacked=True).set(title="Goals and Assists")
plt.ylabel("Goals + Assists")
plt.xlabel("Player Names")
plt.show()

# %%
overall_data.head(20).plot.bar( y='Goals', rot=90, figsize=(10,6)).set(title = "Total Number of Goals scored by Clubs")
plt.ylabel("Total Goals")
plt.xlabel("Clubs")
# Out:
# Text(0.5, 0, 'Clubs')

# %%
overall_data.head(20).plot.bar( y=['Goals', 'Assists', 'Penalty_Goals'], rot=90, figsize=(10,6))
plt.ylabel("Goals, Assists and Penalties")
# Out:
# Text(0, 0.5, 'Goals, Assists and Penalties')

# %%
overall_data.head(20).plot.bar( y=['Goals', 'Assists'], rot=90, figsize=(10,6), stacked=True)
plt.ylabel("Goals + Assists")
# Out:
# Text(0, 0.5, 'Goals + Assists')

# %%
plt.scatter(golden_boot.Goals.head(20), golden_boot.Assists.head(20))
plt.grid()

# %%
sns.regplot(data=epl_df, y='xG',  x='Goals', color='c')
# Out:
# <AxesSubplot:xlabel='Goals', ylabel='xG'>

# %%
plt.scatter(golden_boot.Goals.head(20), golden_boot.xG.head(20), color='g')
plt.scatter(golden_boot.Assists.head(20), golden_boot.xA.head(20), color='b')

# %%
plt.scatter(epl_df['Goals'], epl_df['xG'], color = 'g', alpha=0.6)
plt.title('Goals vs xG')
plt.xlabel('Goals')
plt.ylabel('xG')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(data = epl_df, y = "Goals", x = "xG", color = "c").set(title = "Goals vs xG")
# Out:
# [Text(0.5, 1.0, 'Goals vs xG')]
